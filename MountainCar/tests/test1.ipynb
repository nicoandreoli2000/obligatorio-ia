# %%
import matplotlib.pyplot as plt
import numpy as np
from MountainCarEnv import MountainCarEnv


pos_space = np.linspace(-1.2, 0.6, 12)
vel_space = np.linspace(-0.07, 0.07, 20)

def get_state(observation):
    pos, vel =  observation
    pos_bin = int(np.digitize(pos, pos_space))
    vel_bin = int(np.digitize(vel, vel_space))

    return (pos_bin, vel_bin)

def max_action(Q, state, actions=[0, 1, 2]):
    values = np.array([Q[state,a] for a in actions])
    action = np.argmax(values)

    return action

if __name__ == '__main__':
    env = MountainCarEnv(render_mode='rgb_array')
    env._max_episode_steps = 1000
    n_games = 50000
    alpha = 0.1
    gamma = 0.99
    eps = 1.0

    action_space = [0, 1, 2]

    states = []
    for pos in range(21):
        for vel in range(21):
            states.append((pos, vel))

    Q = {}
    for state in states:
        for action in action_space:
            Q[state, action] = 0

    score = 0
    total_rewards = np.zeros(n_games)
    for i in range(n_games):
        done = False
        obs = env.reset()
        state = get_state(obs)
        if i % 100 == 0 and i > 0:
            print('episode ', i, 'score ', score, 'epsilon %.3f' % eps)
        score = 0
        while not done:
            action = np.random.choice([0,1,2]) if np.random.random() < eps \
                    else max_action(Q, state)
            obs_, reward, done, info = env.step(action)
            state_ = get_state(obs_)
            score += reward
            action_ = max_action(Q, state_)
            Q[state, action] = Q[state, action] + \
                    alpha*(reward + gamma*Q[state_, action_] - Q[state, action])
            state = state_
        total_rewards[i] = score
        eps = eps - 2/n_games if eps > 0.01 else 0.01

    mean_rewards = np.zeros(n_games)
    for t in range(n_games):
        mean_rewards[t] = np.mean(total_rewards[max(0, t-50):(t+1)])
    plt.plot(mean_rewards)
    plt.savefig('mountaincar.png')
# Out:
# episode  100 score  -1000.0 epsilon 0.996
# episode  200 score  -1000.0 epsilon 0.992
# episode  300 score  -1000.0 epsilon 0.988
# episode  400 score  -1000.0 epsilon 0.984
# episode  500 score  -1000.0 epsilon 0.980
# episode  600 score  -1000.0 epsilon 0.976
# episode  700 score  -1000.0 epsilon 0.972
# episode  800 score  -1000.0 epsilon 0.968
# episode  900 score  -1000.0 epsilon 0.964
# episode  1000 score  -1000.0 epsilon 0.960
# episode  1100 score  -1000.0 epsilon 0.956
# episode  1200 score  -1000.0 epsilon 0.952
# episode  1300 score  -1000.0 epsilon 0.948
# episode  1400 score  -1000.0 epsilon 0.944
# episode  1500 score  -1000.0 epsilon 0.940
# episode  1600 score  -1000.0 epsilon 0.936
# episode  1700 score  -1000.0 epsilon 0.932
# episode  1800 score  -1000.0 epsilon 0.928
# episode  1900 score  -1000.0 epsilon 0.924
# episode  2000 score  -1000.0 epsilon 0.920
# episode  2100 score  -1000.0 epsilon 0.916
# episode  2200 score  -1000.0 epsilon 0.912
# episode  2300 score  -1000.0 epsilon 0.908
# episode  2400 score  -1000.0 epsilon 0.904
# episode  2500 score  -1000.0 epsilon 0.900
# episode  2600 score  -1000.0 epsilon 0.896
# episode  2700 score  -1000.0 epsilon 0.892
# episode  2800 score  -1000.0 epsilon 0.888
# episode  2900 score  -1000.0 epsilon 0.884
# episode  3000 score  -1000.0 epsilon 0.880
# episode  3100 score  -1000.0 epsilon 0.876
# episode  3200 score  -1000.0 epsilon 0.872
# episode  3300 score  -872.0 epsilon 0.868
# episode  3400 score  -1000.0 epsilon 0.864
# episode  3500 score  -1000.0 epsilon 0.860
# episode  3600 score  -1000.0 epsilon 0.856
# episode  3700 score  -1000.0 epsilon 0.852
# episode  3800 score  -1000.0 epsilon 0.848
# episode  3900 score  -1000.0 epsilon 0.844
# episode  4000 score  -1000.0 epsilon 0.840
# episode  4100 score  -1000.0 epsilon 0.836
# episode  4200 score  -1000.0 epsilon 0.832
# episode  4300 score  -877.0 epsilon 0.828
# episode  4400 score  -663.0 epsilon 0.824
# episode  4500 score  -875.0 epsilon 0.820
# episode  4600 score  -1000.0 epsilon 0.816
# episode  4700 score  -1000.0 epsilon 0.812
# episode  4800 score  -1000.0 epsilon 0.808
# episode  4900 score  -1000.0 epsilon 0.804
# episode  5000 score  -824.0 epsilon 0.800
# episode  5100 score  -1000.0 epsilon 0.796
# episode  5200 score  -924.0 epsilon 0.792
# episode  5300 score  -1000.0 epsilon 0.788
# episode  5400 score  -473.0 epsilon 0.784
# episode  5500 score  -868.0 epsilon 0.780
# episode  5600 score  -1000.0 epsilon 0.776
# episode  5700 score  -1000.0 epsilon 0.772
# episode  5800 score  -1000.0 epsilon 0.768
# episode  5900 score  -769.0 epsilon 0.764
# episode  6000 score  -1000.0 epsilon 0.760
# episode  6100 score  -780.0 epsilon 0.756
# episode  6200 score  -595.0 epsilon 0.752
# episode  6300 score  -722.0 epsilon 0.748
# episode  6400 score  -1000.0 epsilon 0.744
# episode  6500 score  -1000.0 epsilon 0.740
# episode  6600 score  -725.0 epsilon 0.736
# episode  6700 score  -622.0 epsilon 0.732
# episode  6800 score  -718.0 epsilon 0.728
# episode  6900 score  -1000.0 epsilon 0.724
# episode  7000 score  -1000.0 epsilon 0.720
# episode  7100 score  -1000.0 epsilon 0.716
# episode  7200 score  -670.0 epsilon 0.712
# episode  7300 score  -1000.0 epsilon 0.708
# episode  7400 score  -585.0 epsilon 0.704
# episode  7500 score  -918.0 epsilon 0.700
# episode  7600 score  -1000.0 epsilon 0.696
# episode  7700 score  -1000.0 epsilon 0.692
# episode  7800 score  -393.0 epsilon 0.688
# episode  7900 score  -592.0 epsilon 0.684
# episode  8000 score  -608.0 epsilon 0.680
# episode  8100 score  -1000.0 epsilon 0.676
# episode  8200 score  -569.0 epsilon 0.672
# episode  8300 score  -889.0 epsilon 0.668
# episode  8400 score  -1000.0 epsilon 0.664
# episode  8500 score  -1000.0 epsilon 0.660
# episode  8600 score  -767.0 epsilon 0.656
# episode  8700 score  -1000.0 epsilon 0.652
# episode  8800 score  -413.0 epsilon 0.648
# episode  8900 score  -386.0 epsilon 0.644
# episode  9000 score  -442.0 epsilon 0.640
# episode  9100 score  -684.0 epsilon 0.636
# episode  9200 score  -890.0 epsilon 0.632
# episode  9300 score  -328.0 epsilon 0.628
# episode  9400 score  -816.0 epsilon 0.624
# episode  9500 score  -336.0 epsilon 0.620
# episode  9600 score  -1000.0 epsilon 0.616
# episode  9700 score  -527.0 epsilon 0.612
# episode  9800 score  -395.0 epsilon 0.608
# episode  9900 score  -501.0 epsilon 0.604
# episode  10000 score  -349.0 epsilon 0.600
# episode  10100 score  -466.0 epsilon 0.596
# episode  10200 score  -701.0 epsilon 0.592
# episode  10300 score  -350.0 epsilon 0.588
# episode  10400 score  -1000.0 epsilon 0.584
# episode  10500 score  -256.0 epsilon 0.580
# episode  10600 score  -914.0 epsilon 0.576
# episode  10700 score  -287.0 epsilon 0.572
# episode  10800 score  -727.0 epsilon 0.568
# episode  10900 score  -832.0 epsilon 0.564
# episode  11000 score  -700.0 epsilon 0.560
# episode  11100 score  -630.0 epsilon 0.556
# episode  11200 score  -941.0 epsilon 0.552
# episode  11300 score  -1000.0 epsilon 0.548
# episode  11400 score  -790.0 epsilon 0.544
# episode  11500 score  -466.0 epsilon 0.540
# episode  11600 score  -248.0 epsilon 0.536
# episode  11700 score  -406.0 epsilon 0.532
# episode  11800 score  -518.0 epsilon 0.528
# episode  11900 score  -240.0 epsilon 0.524
# episode  12000 score  -1000.0 epsilon 0.520
# episode  12100 score  -1000.0 epsilon 0.516
# episode  12200 score  -1000.0 epsilon 0.512
# episode  12300 score  -477.0 epsilon 0.508
# episode  12400 score  -414.0 epsilon 0.504
# episode  12500 score  -315.0 epsilon 0.500
# episode  12600 score  -1000.0 epsilon 0.496
# episode  12700 score  -380.0 epsilon 0.492
# episode  12800 score  -384.0 epsilon 0.488
# episode  12900 score  -359.0 epsilon 0.484
# episode  13000 score  -352.0 epsilon 0.480
# episode  13100 score  -608.0 epsilon 0.476
# episode  13200 score  -271.0 epsilon 0.472
# episode  13300 score  -332.0 epsilon 0.468
# episode  13400 score  -737.0 epsilon 0.464
# episode  13500 score  -419.0 epsilon 0.460
# episode  13600 score  -345.0 epsilon 0.456
# episode  13700 score  -498.0 epsilon 0.452
# episode  13800 score  -243.0 epsilon 0.448
# episode  13900 score  -485.0 epsilon 0.444
# episode  14000 score  -332.0 epsilon 0.440
# episode  14100 score  -249.0 epsilon 0.436
# episode  14200 score  -395.0 epsilon 0.432
# episode  14300 score  -488.0 epsilon 0.428
# episode  14400 score  -258.0 epsilon 0.424
# episode  14500 score  -239.0 epsilon 0.420
# episode  14600 score  -289.0 epsilon 0.416
# episode  14700 score  -533.0 epsilon 0.412
# episode  14800 score  -744.0 epsilon 0.408
# episode  14900 score  -259.0 epsilon 0.404
# episode  15000 score  -242.0 epsilon 0.400
# episode  15100 score  -260.0 epsilon 0.396
# episode  15200 score  -355.0 epsilon 0.392
# episode  15300 score  -327.0 epsilon 0.388
# episode  15400 score  -351.0 epsilon 0.384
# episode  15500 score  -309.0 epsilon 0.380
# episode  15600 score  -327.0 epsilon 0.376
# episode  15700 score  -287.0 epsilon 0.372
# episode  15800 score  -344.0 epsilon 0.368
# episode  15900 score  -356.0 epsilon 0.364
# episode  16000 score  -178.0 epsilon 0.360
# episode  16100 score  -325.0 epsilon 0.356
# episode  16200 score  -242.0 epsilon 0.352
# episode  16300 score  -264.0 epsilon 0.348
# episode  16400 score  -237.0 epsilon 0.344
# episode  16500 score  -223.0 epsilon 0.340
# episode  16600 score  -212.0 epsilon 0.336
# episode  16700 score  -163.0 epsilon 0.332
# episode  16800 score  -349.0 epsilon 0.328
# episode  16900 score  -599.0 epsilon 0.324
# episode  17000 score  -276.0 epsilon 0.320
# episode  17100 score  -212.0 epsilon 0.316
# episode  17200 score  -169.0 epsilon 0.312
# episode  17300 score  -301.0 epsilon 0.308
# episode  17400 score  -323.0 epsilon 0.304
# episode  17500 score  -263.0 epsilon 0.300
# episode  17600 score  -583.0 epsilon 0.296
# episode  17700 score  -242.0 epsilon 0.292
# episode  17800 score  -196.0 epsilon 0.288
# episode  17900 score  -237.0 epsilon 0.284
# episode  18000 score  -233.0 epsilon 0.280
# episode  18100 score  -276.0 epsilon 0.276
# episode  18200 score  -365.0 epsilon 0.272
# episode  18300 score  -225.0 epsilon 0.268
# episode  18400 score  -157.0 epsilon 0.264
# episode  18500 score  -172.0 epsilon 0.260
# episode  18600 score  -235.0 epsilon 0.256
# episode  18700 score  -226.0 epsilon 0.252
# episode  18800 score  -309.0 epsilon 0.248
# episode  18900 score  -243.0 epsilon 0.244
# episode  19000 score  -273.0 epsilon 0.240
# episode  19100 score  -222.0 epsilon 0.236
# episode  19200 score  -175.0 epsilon 0.232
# episode  19300 score  -163.0 epsilon 0.228
# episode  19400 score  -254.0 epsilon 0.224
# episode  19500 score  -164.0 epsilon 0.220
# episode  19600 score  -177.0 epsilon 0.216
# episode  19700 score  -170.0 epsilon 0.212
# episode  19800 score  -255.0 epsilon 0.208
# episode  19900 score  -474.0 epsilon 0.204
# episode  20000 score  -241.0 epsilon 0.200
# episode  20100 score  -233.0 epsilon 0.196
# episode  20200 score  -259.0 epsilon 0.192
# episode  20300 score  -194.0 epsilon 0.188
# episode  20400 score  -154.0 epsilon 0.184
# episode  20500 score  -179.0 epsilon 0.180
# episode  20600 score  -276.0 epsilon 0.176
# episode  20700 score  -151.0 epsilon 0.172
# episode  20800 score  -148.0 epsilon 0.168
# episode  20900 score  -150.0 epsilon 0.164
# episode  21000 score  -149.0 epsilon 0.160
# episode  21100 score  -692.0 epsilon 0.156
# episode  21200 score  -157.0 epsilon 0.152
# episode  21300 score  -190.0 epsilon 0.148
# episode  21400 score  -230.0 epsilon 0.144
# episode  21500 score  -151.0 epsilon 0.140
# episode  21600 score  -166.0 epsilon 0.136
# episode  21700 score  -237.0 epsilon 0.132
# episode  21800 score  -185.0 epsilon 0.128
# episode  21900 score  -191.0 epsilon 0.124
# episode  22000 score  -154.0 epsilon 0.120
# episode  22100 score  -189.0 epsilon 0.116
# episode  22200 score  -157.0 epsilon 0.112
# episode  22300 score  -165.0 epsilon 0.108
# episode  22400 score  -210.0 epsilon 0.104
# episode  22500 score  -145.0 epsilon 0.100
# episode  22600 score  -235.0 epsilon 0.096
# episode  22700 score  -132.0 epsilon 0.092
# episode  22800 score  -155.0 epsilon 0.088
# episode  22900 score  -168.0 epsilon 0.084
# episode  23000 score  -163.0 epsilon 0.080
# episode  23100 score  -187.0 epsilon 0.076
# episode  23200 score  -164.0 epsilon 0.072
# episode  23300 score  -158.0 epsilon 0.068
# episode  23400 score  -351.0 epsilon 0.064
# episode  23500 score  -182.0 epsilon 0.060
# episode  23600 score  -212.0 epsilon 0.056
# episode  23700 score  -154.0 epsilon 0.052
# episode  23800 score  -176.0 epsilon 0.048
# episode  23900 score  -146.0 epsilon 0.044
# episode  24000 score  -148.0 epsilon 0.040
# episode  24100 score  -151.0 epsilon 0.036
# episode  24200 score  -149.0 epsilon 0.032
# episode  24300 score  -192.0 epsilon 0.028
# episode  24400 score  -171.0 epsilon 0.024
# episode  24500 score  -148.0 epsilon 0.020
# episode  24600 score  -234.0 epsilon 0.016
# episode  24700 score  -154.0 epsilon 0.012
# episode  24800 score  -157.0 epsilon 0.010
# episode  24900 score  -149.0 epsilon 0.010
# episode  25000 score  -220.0 epsilon 0.010
# episode  25100 score  -204.0 epsilon 0.010
# episode  25200 score  -118.0 epsilon 0.010
# episode  25300 score  -146.0 epsilon 0.010
# episode  25400 score  -141.0 epsilon 0.010
# episode  25500 score  -200.0 epsilon 0.010
# episode  25600 score  -200.0 epsilon 0.010
# episode  25700 score  -146.0 epsilon 0.010
# episode  25800 score  -145.0 epsilon 0.010
# episode  25900 score  -153.0 epsilon 0.010
# episode  26000 score  -155.0 epsilon 0.010
# episode  26100 score  -158.0 epsilon 0.010
# episode  26200 score  -415.0 epsilon 0.010
# episode  26300 score  -185.0 epsilon 0.010
# episode  26400 score  -146.0 epsilon 0.010
# episode  26500 score  -148.0 epsilon 0.010
# episode  26600 score  -134.0 epsilon 0.010
# episode  26700 score  -116.0 epsilon 0.010
# episode  26800 score  -475.0 epsilon 0.010
# episode  26900 score  -140.0 epsilon 0.010
# episode  27000 score  -185.0 epsilon 0.010
# episode  27100 score  -190.0 epsilon 0.010
# episode  27200 score  -185.0 epsilon 0.010
# episode  27300 score  -217.0 epsilon 0.010
# episode  27400 score  -142.0 epsilon 0.010
# episode  27500 score  -151.0 epsilon 0.010
# episode  27600 score  -144.0 epsilon 0.010
# episode  27700 score  -146.0 epsilon 0.010
# episode  27800 score  -180.0 epsilon 0.010
# episode  27900 score  -337.0 epsilon 0.010
# episode  28000 score  -213.0 epsilon 0.010
# episode  28100 score  -152.0 epsilon 0.010
# episode  28200 score  -249.0 epsilon 0.010
# episode  28300 score  -222.0 epsilon 0.010
# episode  28400 score  -230.0 epsilon 0.010
# episode  28500 score  -154.0 epsilon 0.010
# episode  28600 score  -149.0 epsilon 0.010
# episode  28700 score  -153.0 epsilon 0.010
# episode  28800 score  -205.0 epsilon 0.010
# episode  28900 score  -186.0 epsilon 0.010
# episode  29000 score  -150.0 epsilon 0.010
# episode  29100 score  -150.0 epsilon 0.010
# episode  29200 score  -217.0 epsilon 0.010
# episode  29300 score  -198.0 epsilon 0.010
# episode  29400 score  -389.0 epsilon 0.010
# episode  29500 score  -225.0 epsilon 0.010
# episode  29600 score  -151.0 epsilon 0.010
# episode  29700 score  -204.0 epsilon 0.010
# episode  29800 score  -143.0 epsilon 0.010
# episode  29900 score  -136.0 epsilon 0.010
# episode  30000 score  -207.0 epsilon 0.010
# episode  30100 score  -193.0 epsilon 0.010
# episode  30200 score  -159.0 epsilon 0.010
# episode  30300 score  -243.0 epsilon 0.010
# episode  30400 score  -146.0 epsilon 0.010
# episode  30500 score  -146.0 epsilon 0.010
# episode  30600 score  -145.0 epsilon 0.010
# episode  30700 score  -159.0 epsilon 0.010
# episode  30800 score  -192.0 epsilon 0.010
# episode  30900 score  -191.0 epsilon 0.010
# episode  31000 score  -283.0 epsilon 0.010
# episode  31100 score  -157.0 epsilon 0.010
# episode  31200 score  -223.0 epsilon 0.010
# episode  31300 score  -191.0 epsilon 0.010
# episode  31400 score  -143.0 epsilon 0.010
# episode  31500 score  -212.0 epsilon 0.010
# episode  31600 score  -212.0 epsilon 0.010
# episode  31700 score  -186.0 epsilon 0.010
# episode  31800 score  -188.0 epsilon 0.010
# episode  31900 score  -155.0 epsilon 0.010
# episode  32000 score  -154.0 epsilon 0.010
# episode  32100 score  -171.0 epsilon 0.010
# episode  32200 score  -153.0 epsilon 0.010
# episode  32300 score  -161.0 epsilon 0.010
# episode  32400 score  -164.0 epsilon 0.010
# episode  32500 score  -184.0 epsilon 0.010
# episode  32600 score  -154.0 epsilon 0.010
# episode  32700 score  -153.0 epsilon 0.010
# episode  32800 score  -156.0 epsilon 0.010
# episode  32900 score  -113.0 epsilon 0.010
# episode  33000 score  -133.0 epsilon 0.010
# episode  33100 score  -153.0 epsilon 0.010
# episode  33200 score  -269.0 epsilon 0.010
# episode  33300 score  -153.0 epsilon 0.010
# episode  33400 score  -185.0 epsilon 0.010
# episode  33500 score  -150.0 epsilon 0.010
# episode  33600 score  -148.0 epsilon 0.010
# episode  33700 score  -160.0 epsilon 0.010
# episode  33800 score  -131.0 epsilon 0.010
# episode  33900 score  -146.0 epsilon 0.010
# episode  34000 score  -152.0 epsilon 0.010
# episode  34100 score  -159.0 epsilon 0.010
# episode  34200 score  -168.0 epsilon 0.010
# episode  34300 score  -143.0 epsilon 0.010
# episode  34400 score  -141.0 epsilon 0.010
# episode  34500 score  -138.0 epsilon 0.010
# episode  34600 score  -181.0 epsilon 0.010
# episode  34700 score  -196.0 epsilon 0.010
# episode  34800 score  -145.0 epsilon 0.010
# episode  34900 score  -158.0 epsilon 0.010
# episode  35000 score  -184.0 epsilon 0.010
# episode  35100 score  -146.0 epsilon 0.010
# episode  35200 score  -176.0 epsilon 0.010
# episode  35300 score  -238.0 epsilon 0.010
# episode  35400 score  -145.0 epsilon 0.010
# episode  35500 score  -148.0 epsilon 0.010
# episode  35600 score  -140.0 epsilon 0.010
# episode  35700 score  -139.0 epsilon 0.010
# episode  35800 score  -141.0 epsilon 0.010
# episode  35900 score  -139.0 epsilon 0.010
# episode  36000 score  -140.0 epsilon 0.010
# episode  36100 score  -140.0 epsilon 0.010
# episode  36200 score  -143.0 epsilon 0.010
# episode  36300 score  -142.0 epsilon 0.010
# episode  36400 score  -140.0 epsilon 0.010
# episode  36500 score  -142.0 epsilon 0.010
# episode  36600 score  -143.0 epsilon 0.010
# episode  36700 score  -217.0 epsilon 0.010
# episode  36800 score  -150.0 epsilon 0.010
# episode  36900 score  -234.0 epsilon 0.010
# episode  37000 score  -208.0 epsilon 0.010
# episode  37100 score  -137.0 epsilon 0.010
# episode  37200 score  -184.0 epsilon 0.010
# episode  37300 score  -139.0 epsilon 0.010
# episode  37400 score  -202.0 epsilon 0.010
# episode  37500 score  -152.0 epsilon 0.010
# episode  37600 score  -236.0 epsilon 0.010
# episode  37700 score  -220.0 epsilon 0.010
# episode  37800 score  -208.0 epsilon 0.010
# episode  37900 score  -180.0 epsilon 0.010
# episode  38000 score  -179.0 epsilon 0.010
# episode  38100 score  -150.0 epsilon 0.010
# episode  38200 score  -199.0 epsilon 0.010
# episode  38300 score  -156.0 epsilon 0.010
# episode  38400 score  -240.0 epsilon 0.010
# episode  38500 score  -667.0 epsilon 0.010
# episode  38600 score  -191.0 epsilon 0.010
# episode  38700 score  -299.0 epsilon 0.010
# episode  38800 score  -204.0 epsilon 0.010
# episode  38900 score  -119.0 epsilon 0.010
# episode  39000 score  -192.0 epsilon 0.010
# episode  39100 score  -163.0 epsilon 0.010
# episode  39200 score  -237.0 epsilon 0.010
# episode  39300 score  -222.0 epsilon 0.010
# episode  39400 score  -212.0 epsilon 0.010
# episode  39500 score  -160.0 epsilon 0.010
# episode  39600 score  -156.0 epsilon 0.010
# episode  39700 score  -148.0 epsilon 0.010
# episode  39800 score  -144.0 epsilon 0.010
# episode  39900 score  -224.0 epsilon 0.010
# episode  40000 score  -221.0 epsilon 0.010
# episode  40100 score  -146.0 epsilon 0.010
# episode  40200 score  -199.0 epsilon 0.010
# episode  40300 score  -147.0 epsilon 0.010
# episode  40400 score  -144.0 epsilon 0.010
# episode  40500 score  -124.0 epsilon 0.010
# episode  40600 score  -128.0 epsilon 0.010
# episode  40700 score  -282.0 epsilon 0.010
# episode  40800 score  -188.0 epsilon 0.010
# episode  40900 score  -198.0 epsilon 0.010
# episode  41000 score  -149.0 epsilon 0.010
# episode  41100 score  -153.0 epsilon 0.010
# episode  41200 score  -227.0 epsilon 0.010
# episode  41300 score  -146.0 epsilon 0.010
# episode  41400 score  -207.0 epsilon 0.010
# episode  41500 score  -201.0 epsilon 0.010
# episode  41600 score  -208.0 epsilon 0.010
# episode  41700 score  -218.0 epsilon 0.010
# episode  41800 score  -154.0 epsilon 0.010
# episode  41900 score  -270.0 epsilon 0.010
# episode  42000 score  -152.0 epsilon 0.010
# episode  42100 score  -153.0 epsilon 0.010
# episode  42200 score  -153.0 epsilon 0.010
# episode  42300 score  -188.0 epsilon 0.010
# episode  42400 score  -206.0 epsilon 0.010
# episode  42500 score  -153.0 epsilon 0.010
# episode  42600 score  -185.0 epsilon 0.010
# episode  42700 score  -145.0 epsilon 0.010
# episode  42800 score  -143.0 epsilon 0.010
# episode  42900 score  -419.0 epsilon 0.010
# episode  43000 score  -173.0 epsilon 0.010
# episode  43100 score  -115.0 epsilon 0.010
# episode  43200 score  -164.0 epsilon 0.010
# episode  43300 score  -156.0 epsilon 0.010
# episode  43400 score  -329.0 epsilon 0.010
# episode  43500 score  -296.0 epsilon 0.010
# episode  43600 score  -199.0 epsilon 0.010
# episode  43700 score  -163.0 epsilon 0.010
# episode  43800 score  -157.0 epsilon 0.010
# episode  43900 score  -190.0 epsilon 0.010
# episode  44000 score  -142.0 epsilon 0.010
# episode  44100 score  -185.0 epsilon 0.010
# episode  44200 score  -203.0 epsilon 0.010
# episode  44300 score  -238.0 epsilon 0.010
# episode  44400 score  -208.0 epsilon 0.010
# episode  44500 score  -261.0 epsilon 0.010
# episode  44600 score  -222.0 epsilon 0.010
# episode  44700 score  -241.0 epsilon 0.010
# episode  44800 score  -145.0 epsilon 0.010
# episode  44900 score  -162.0 epsilon 0.010
# episode  45000 score  -148.0 epsilon 0.010
# episode  45100 score  -376.0 epsilon 0.010
# episode  45200 score  -232.0 epsilon 0.010
# episode  45300 score  -235.0 epsilon 0.010
# episode  45400 score  -192.0 epsilon 0.010
# episode  45500 score  -168.0 epsilon 0.010
# episode  45600 score  -141.0 epsilon 0.010
# episode  45700 score  -208.0 epsilon 0.010
# episode  45800 score  -215.0 epsilon 0.010
# episode  45900 score  -159.0 epsilon 0.010
# episode  46000 score  -150.0 epsilon 0.010
# episode  46100 score  -155.0 epsilon 0.010
# episode  46200 score  -152.0 epsilon 0.010
# episode  46300 score  -211.0 epsilon 0.010
# episode  46400 score  -140.0 epsilon 0.010
# episode  46500 score  -204.0 epsilon 0.010
# episode  46600 score  -112.0 epsilon 0.010
# episode  46700 score  -146.0 epsilon 0.010
# episode  46800 score  -145.0 epsilon 0.010
# episode  46900 score  -190.0 epsilon 0.010
# episode  47000 score  -146.0 epsilon 0.010
# episode  47100 score  -148.0 epsilon 0.010
# episode  47200 score  -180.0 epsilon 0.010
# episode  47300 score  -147.0 epsilon 0.010
# episode  47400 score  -151.0 epsilon 0.010
# episode  47500 score  -348.0 epsilon 0.010
# episode  47600 score  -286.0 epsilon 0.010
# episode  47700 score  -140.0 epsilon 0.010
# episode  47800 score  -151.0 epsilon 0.010
# episode  47900 score  -189.0 epsilon 0.010
# episode  48000 score  -190.0 epsilon 0.010
# episode  48100 score  -157.0 epsilon 0.010
# episode  48200 score  -146.0 epsilon 0.010
# episode  48300 score  -149.0 epsilon 0.010
# episode  48400 score  -222.0 epsilon 0.010
# episode  48500 score  -146.0 epsilon 0.010
# episode  48600 score  -157.0 epsilon 0.010
# episode  48700 score  -235.0 epsilon 0.010
# episode  48800 score  -198.0 epsilon 0.010
# episode  48900 score  -148.0 epsilon 0.010
# episode  49000 score  -194.0 epsilon 0.010
# episode  49100 score  -209.0 epsilon 0.010
# episode  49200 score  -143.0 epsilon 0.010
# episode  49300 score  -142.0 epsilon 0.010
# episode  49400 score  -150.0 epsilon 0.010
# episode  49500 score  -389.0 epsilon 0.010
# episode  49600 score  -134.0 epsilon 0.010
# episode  49700 score  -150.0 epsilon 0.010
# episode  49800 score  -130.0 epsilon 0.010
# episode  49900 score  -170.0 epsilon 0.010
